# %% [markdown]
# <a href="https://colab.research.google.com/github/Saskia23/sentimen-twitter-nb/blob/main/sentimen_twitter_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8639693a-3dc4-4f01-bac3-02bd57725877" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8639693a-3dc4-4f01-bac3-02bd57725877">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
with zipfile.ZipFile("Tweets.csv.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %%
import pandas as pd
df = pd.read_csv("Tweets.csv")
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
# @title airline vs airline_sentiment_gold

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['airline_sentiment_gold'].value_counts()
    for x_label, grp in df.groupby('airline')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('airline')
_ = plt.ylabel('airline_sentiment_gold')

# %%
# @title tweet_id

from matplotlib import pyplot as plt
df['tweet_id'].plot(kind='hist', bins=20, title='tweet_id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title airline_sentiment vs airline_sentiment_confidence

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['airline_sentiment'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='airline_sentiment_confidence', y='airline_sentiment', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /tmp/ipython-input-27-2681895590.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='airline_sentiment_confidence', y='airline_sentiment', inner='box', palette='Dark2')

# %%
# @title airline_sentiment_gold vs tweet_id

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['airline_sentiment_gold'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='tweet_id', y='airline_sentiment_gold', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /tmp/ipython-input-26-1605807219.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='tweet_id', y='airline_sentiment_gold', inner='box', palette='Dark2')

# %%
# @title airline vs tweet_id

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['airline'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='tweet_id', y='airline', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# @title airline_sentiment vs tweet_id

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['airline_sentiment'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='tweet_id', y='airline_sentiment', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /tmp/ipython-input-24-3057696469.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df, x='tweet_id', y='airline_sentiment', inner='box', palette='Dark2')

# %%
# @title airline vs airline_sentiment_gold

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['airline_sentiment_gold'].value_counts()
    for x_label, grp in df.groupby('airline')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('airline')
_ = plt.ylabel('airline_sentiment_gold')

# %%
# @title airline_sentiment vs airline

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['airline'].value_counts()
    for x_label, grp in df.groupby('airline_sentiment')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('airline_sentiment')
_ = plt.ylabel('airline')

# %%
# @title retweet_count

from matplotlib import pyplot as plt
df['retweet_count'].plot(kind='line', figsize=(8, 4), title='retweet_count')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title negativereason_confidence

from matplotlib import pyplot as plt
df['negativereason_confidence'].plot(kind='line', figsize=(8, 4), title='negativereason_confidence')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title airline_sentiment_confidence

from matplotlib import pyplot as plt
df['airline_sentiment_confidence'].plot(kind='line', figsize=(8, 4), title='airline_sentiment_confidence')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title tweet_id

from matplotlib import pyplot as plt
df['tweet_id'].plot(kind='line', figsize=(8, 4), title='tweet_id')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title negativereason_confidence vs retweet_count

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='negativereason_confidence', y='retweet_count', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-16-1572743936.py in <cell line: 0>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=df)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display, backend)
#     147       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     148     self._credentials = credentials
# --> 149     self._ensure_gspread_client()
#     150
#     151     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     217     global _gspread_client
#     218     if _gspread_client is None:
# --> 219       creds = InteractiveSheet.generate_creds(self._credentials)
# ...

# %%
# @title airline_sentiment_confidence vs negativereason_confidence

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='airline_sentiment_confidence', y='negativereason_confidence', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title tweet_id vs airline_sentiment_confidence

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='tweet_id', y='airline_sentiment_confidence', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title airline_sentiment_gold

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('airline_sentiment_gold').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title airline

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('airline').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title airline_sentiment

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('airline_sentiment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title retweet_count

from matplotlib import pyplot as plt
df['retweet_count'].plot(kind='hist', bins=20, title='retweet_count')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title negativereason_confidence

from matplotlib import pyplot as plt
df['negativereason_confidence'].plot(kind='hist', bins=20, title='negativereason_confidence')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title airline_sentiment_confidence

from matplotlib import pyplot as plt
df['airline_sentiment_confidence'].plot(kind='hist', bins=20, title='airline_sentiment_confidence')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title negativereason_confidence

from matplotlib import pyplot as plt
df['negativereason_confidence'].plot(kind='hist', bins=20, title='negativereason_confidence')
plt.gca().spines[['top', 'right',]].set_visible(False)
